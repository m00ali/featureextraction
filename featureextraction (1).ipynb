# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import spacy as sp
from spacy.lang.en.stop_words import STOP_WORDS
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import pandas as pd

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
from nltk.tokenize import sent_tokenize

# %%
import re

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# **DATASET INFORMATION**

# %%
df=pd.read_csv('train.csv', encoding='latin1')

# %%
df=df[['sentiment','text']]

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (27480, 2)

# %%
df
# Out:
#       sentiment                                               text
# 0       neutral                I`d have responded, if I were going
# 1      negative      Sooo SAD I will miss you here in San Diego!!!
# 2      negative                          my boss is bullying me...
# 3      negative                     what interview! leave me alone
# 4      negative   Sons of ****, why couldn`t they put them on t...
# ...         ...                                                ...
# 27476  negative   wish we could come see u on Denver  husband l...
# 27477  negative   I`ve wondered about rake to.  The client has ...
# 27478  positive   Yay good for both of you. Enjoy the break - y...
# 27479  positive                         But it was worth it  ****.
# 27480   neutral     All this flirting going on - The ATG smiles...
#
# [27480 rows x 2 columns]

# %% [markdown]
# **PREPROCESSING OF TEXT**

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

for index, row in df.iterrows():
    text = row['text']
    tokens = word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalpha() and not token in stop_words]  # Lemmatize,filter out non-alphabetic tokens,remove stopwords
    dataaa = " ".join(tokens)
    df.at[index, 'processed__text'] = dataaa

# %%
df
# Out:
#       sentiment                                               text  \
# 0       neutral                I`d have responded, if I were going
# 1      negative      Sooo SAD I will miss you here in San Diego!!!
# 2      negative                          my boss is bullying me...
# 3      negative                     what interview! leave me alone
# 4      negative   Sons of ****, why couldn`t they put them on t...
# ...         ...                                                ...
# 27476  negative   wish we could come see u on Denver  husband l...
# 27477  negative   I`ve wondered about rake to.  The client has ...
# 27478  positive   Yay good for both of you. Enjoy the break - y...
# 27479  positive                         But it was worth it  ****.
# 27480   neutral     All this flirting going on - The ATG smiles...
#
#                                          processed__text
# 0                                        responded going
# 1                                sooo sad miss san diego
# 2                                           bos bullying
# 3                                  interview leave alone
# 4                         son put release already bought
# ...                                                  ...
# 27476  wish could come see u denver husband lost job ...
# 27477  wondered rake client made clear force devs lea...
# 27478  yay good enjoy break probably need hectic week...
# 27479                                              worth
# 27480                   flirting going atg smile yay hug
#
# [27480 rows x 3 columns]

# %% [markdown]
# **EMOJI EXTRACTION**

# %%
def extract_emojis(text):
    emoji_pattern = re.compile("["
                               "\U0001F600-\U0001F64F"  # Emoticons
                               "\U0001F300-\U0001F5FF"  # Symbols & Pictographs
                               "\U0001F680-\U0001F6FF"  # Transport & Map Symbols
                               "\U0001F1E0-\U0001F1FF"  # Flags (iOS)
                               "]+", flags=re.UNICODE)
    emojis = emoji_pattern.findall(text)
    return emojis

# %%
df['Emojis'] = df['text'].apply(lambda x: extract_emojis(x))

# %%
df
# Out:
#       sentiment                                               text  \
# 0       neutral                I`d have responded, if I were going
# 1      negative      Sooo SAD I will miss you here in San Diego!!!
# 2      negative                          my boss is bullying me...
# 3      negative                     what interview! leave me alone
# 4      negative   Sons of ****, why couldn`t they put them on t...
# ...         ...                                                ...
# 27476  negative   wish we could come see u on Denver  husband l...
# 27477  negative   I`ve wondered about rake to.  The client has ...
# 27478  positive   Yay good for both of you. Enjoy the break - y...
# 27479  positive                         But it was worth it  ****.
# 27480   neutral     All this flirting going on - The ATG smiles...
#
#                                          processed__text Emojis
# 0                                        responded going     []
# 1                                sooo sad miss san diego     []
# 2                                           bos bullying     []
# 3                                  interview leave alone     []
# 4                         son put release already bought     []
# ...                                                  ...    ...
# 27476  wish could come see u denver husband lost job ...     []
# 27477  wondered rake client made clear force devs lea...     []
# 27478  yay good enjoy break probably need hectic week...     []
# 27479                                              worth     []
# 27480                   flirting going atg smile yay hug     []
#
# [27480 rows x 4 columns]

# %% [markdown]
# **EXCLAMATION MARK EXTRACTION**

# %%
def extract_exclamation_marks(text):
    exclamation_marks = re.findall(r'!', text)
    return exclamation_marks

# %%
df['Exclamation Marks'] = df['text'].apply(lambda x: extract_exclamation_marks(x))

# %%
df
# Out:
#       sentiment                                               text  \
# 0       neutral                I`d have responded, if I were going
# 1      negative      Sooo SAD I will miss you here in San Diego!!!
# 2      negative                          my boss is bullying me...
# 3      negative                     what interview! leave me alone
# 4      negative   Sons of ****, why couldn`t they put them on t...
# ...         ...                                                ...
# 27476  negative   wish we could come see u on Denver  husband l...
# 27477  negative   I`ve wondered about rake to.  The client has ...
# 27478  positive   Yay good for both of you. Enjoy the break - y...
# 27479  positive                         But it was worth it  ****.
# 27480   neutral     All this flirting going on - The ATG smiles...
#
#                                          processed__text Emojis  \
# 0                                        responded going     []
# 1                                sooo sad miss san diego     []
# 2                                           bos bullying     []
# 3                                  interview leave alone     []
# 4                         son put release already bought     []
# ...                                                  ...    ...
# 27476  wish could come see u denver husband lost job ...     []
# 27477  wondered rake client made clear force devs lea...     []
# 27478  yay good enjoy break probably need hectic week...     []
# 27479                                              worth     []
# 27480                   flirting going atg smile yay hug     []
#
#       Exclamation Marks
# 0                    []
# 1             [!, !, !]
# 2                    []
# 3                   [!]
# 4                    []
# ...                 ...
# 27476                []
# 27477                []
# 27478                []
# 27479                []
# 27480                []
#
# [27480 rows x 5 columns]

# %% [markdown]
# **SENTIMENTAL WORD EXTRACTION**

# %%
def extract_sentiment_words(processed__text):
  sid = SentimentIntensityAnalyzer()
  #posword=set()
  #neuword=set()
  #negword=set()
  #words=text.split()

  posword=0
  negword=0
  neuword=0
  sentences = nltk.sent_tokenize(processed__text)
  for word in sentences:
    words = nltk.word_tokenize(word)
    for x in words:
      score=sid.polarity_scores(x)
      if (score['compound']) >=  0.3:
        posword+=1
      elif (score['compound']) <= -0.3:
        negword+=1
      else:
        neuword+=1

    return posword, negword, neuword

df[['Positive Words', 'Negative Words', 'Neutral Words']] = df['processed__text'].apply(lambda x: pd.Series(extract_sentiment_words(x)))

# %%
df
# Out:
#       sentiment                                               text  \
# 0       neutral                I`d have responded, if I were going
# 1      negative      Sooo SAD I will miss you here in San Diego!!!
# 2      negative                          my boss is bullying me...
# 3      negative                     what interview! leave me alone
# 4      negative   Sons of ****, why couldn`t they put them on t...
# ...         ...                                                ...
# 27476  negative   wish we could come see u on Denver  husband l...
# 27477  negative   I`ve wondered about rake to.  The client has ...
# 27478  positive   Yay good for both of you. Enjoy the break - y...
# 27479  positive                         But it was worth it  ****.
# 27480   neutral     All this flirting going on - The ATG smiles...
#
#                                          processed__text Emojis  \
# 0                                        responded going     []
# 1                                sooo sad miss san diego     []
# 2                                           bos bullying     []
# 3                                  interview leave alone     []
# 4                         son put release already bought     []
# ...                                                  ...    ...
# 27476  wish could come see u denver husband lost job ...     []
# 27477  wondered rake client made clear force devs lea...     []
# 27478  yay good enjoy break probably need hectic week...     []
# 27479                                              worth     []
# 27480                   flirting going atg smile yay hug     []
#
#       Exclamation Marks  Positive Words  Negative Words  Neutral Words
# 0                    []             0.0             0.0            2.0
# 1             [!, !, !]             0.0             1.0            4.0
# 2                    []             0.0             1.0            1.0
# 3                   [!]             0.0             0.0            3.0
# 4                    []             0.0             0.0            5.0
# ...                 ...             ...             ...            ...
# 27476                []             1.0             1.0            8.0
# 27477                []             1.0             0.0           11.0
# 27478                []             4.0             0.0            8.0
# 27479                []             0.0             0.0            1.0
# 27480                []             3.0             0.0            3.0
#
# [27480 rows x 8 columns]
# Warning: total number of rows (27480) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
df=df[['processed__text','Positive Words', 'Negative Words', 'Neutral Words', 'sentiment']]

# %%
df
# Out:
#                                          processed__text  Positive Words  \
# 0                                        responded going             0.0
# 1                                sooo sad miss san diego             0.0
# 2                                           bos bullying             0.0
# 3                                  interview leave alone             0.0
# 4                         son put release already bought             0.0
# ...                                                  ...             ...
# 27476  wish could come see u denver husband lost job ...             1.0
# 27477  wondered rake client made clear force devs lea...             1.0
# 27478  yay good enjoy break probably need hectic week...             4.0
# 27479                                              worth             0.0
# 27480                   flirting going atg smile yay hug             3.0
#
#        Negative Words  Neutral Words sentiment
# 0                 0.0            2.0   neutral
# 1                 1.0            4.0  negative
# 2                 1.0            1.0  negative
# 3                 0.0            3.0  negative
# 4                 0.0            5.0  negative
# ...               ...            ...       ...
# 27476             1.0            8.0  negative
# 27477             0.0           11.0  negative
# 27478             0.0            8.0  positive
# 27479             0.0            1.0  positive
# 27480             0.0            3.0   neutral
#
# [27480 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['sentiment'] = label_encoder.fit_transform(df['sentiment'])

print(df['sentiment'].unique())
# Out:
# [1 0 2]
# <ipython-input-60-ba95f1e57eab>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = label_encoder.fit_transform(df['sentiment'])

# %%
df
# Out:
#                                          processed__text  Positive Words  \
# 0                                        responded going             0.0
# 1                                sooo sad miss san diego             0.0
# 2                                           bos bullying             0.0
# 3                                  interview leave alone             0.0
# 4                         son put release already bought             0.0
# ...                                                  ...             ...
# 27476  wish could come see u denver husband lost job ...             1.0
# 27477  wondered rake client made clear force devs lea...             1.0
# 27478  yay good enjoy break probably need hectic week...             4.0
# 27479                                              worth             0.0
# 27480                   flirting going atg smile yay hug             3.0
#
#        Negative Words  Neutral Words  sentiment
# 0                 0.0            2.0          1
# 1                 1.0            4.0          0
# 2                 1.0            1.0          0
# 3                 0.0            3.0          0
# 4                 0.0            5.0          0
# ...               ...            ...        ...
# 27476             1.0            8.0          0
# 27477             0.0           11.0          0
# 27478             0.0            8.0          2
# 27479             0.0            1.0          2
# 27480             0.0            3.0          1
#
# [27480 rows x 5 columns]

# %%
df.to_csv('extracted.csv')
